# %% [markdown]
# 1. Undirected Graph

# %% [markdown]
# Import library

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# Function cetak plot

# %%
def show_graph(G, pos=None, title='') :
    # Membuat pos jika pos tidak diberikan
    if pos is None:
        pos = nx.spring_layout(G)

    plt.figure(figsize=(15,15))
    nx.draw(
        G, # Graf NetworkX
        pos, # Posisi node
        with_labels=True, # Menampilkan nama node
        node_color='red', # Warna node
        node_size=2000, # Ukuran node
        font_color="white", # Warna font label node
        font_weight="bold", # Ketebalan font label node
        width=2 # Ketebalan garis edge
    )
    edge_labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(
        G,
        pos,
        edge_labels=edge_labels, # Data weight
        font_color='blue', # Warna font label edge
        font_weight="bold", # Berat font label edge
        font_size=12
    )
    plt.margins(0.15) # Memberikan margin pada plot
    plt.title(title) # Menampilkan judul graf jika diberikan
    plt.show() # Menampilkan graf menggunakan matplotlib

# %% [markdown]
# Membuat POS (posisi node)

# %%
pos = {
    'Oradea': (2, 7),
    'Zerind': (1, 6),
    'Arad': (0, 5),
    'Timisoara': (0, 3),
    'Lugoj': (1, 2),
    'Mehadia': (1, 1),
    'Drobeta': (0, 0),
    'Craiova': (2, 0),
    'Rimnicu Vilcea': (3, 3),
    'Sibiu': (3, 5),
    'Fagaras': (5, 5),
    'Pitesti': (4, 2),
    'Bucharest': (6, 1),
    'Giurgiu': (5, 0),
    'Urziceni': (7, 1),
    'Hirsova': (9, 1),
    'Eforie': (9, 0),
    'Vaslui': (8, 3),
    'Iasi': (9, 5),
    'Neamt': (7, 7)
}

# %% [markdown]
# tree dengan NetworkX

# %%
G = nx.Graph()
edges = [
    ('Oradea', 'Zerind', 71),
    ('Oradea', 'Sibiu', 151),
    ('Zerind', 'Arad', 75),
    ('Arad', 'Sibiu', 140),
    ('Arad', 'Timisoara', 118),
    ('Timisoara', 'Lugoj', 111),
    ('Lugoj', 'Mehadia', 70),
    ('Mehadia', 'Drobeta', 75),
    ('Drobeta', 'Craiova', 120),
    ('Craiova', 'Rimnicu Vilcea', 146),
    ('Craiova', 'Pitesti', 138),
    ('Rimnicu Vilcea', 'Sibiu', 80),
    ('Rimnicu Vilcea', 'Pitesti', 97),
    ('Sibiu', 'Fagaras', 99),
    ('Fagaras', 'Bucharest', 211),
    ('Pitesti', 'Bucharest', 101),
    ('Bucharest', 'Giurgiu', 90),
    ('Bucharest', 'Urziceni', 85),
    ('Urziceni', 'Hirsova', 98),
    ('Hirsova', 'Eforie', 86),
    ('Urziceni', 'Vaslui', 142),
    ('Vaslui', 'Iasi', 92),
    ('Iasi', 'Neamt', 87)
]
# Menambahkan edge pada graf
G.add_weighted_edges_from(edges)

# %% [markdown]
# print elemen pada graf

# %%
print("Elemen pada Graf:")
print("Daftar Node pada Graf:", G.nodes())
print("Daftar Edge pada Graf:", G.edges())
print("Jumlah Node pada Graf", G.number_of_nodes())
print("Jumlah Edge pada Graf", G.number_of_edges())
# Out:
# Elemen pada Graf:
# Daftar Node pada Graf: ['Oradea', 'Zerind', 'Sibiu', 'Arad', 'Timisoara', 'Lugoj', 'Mehadia', 'Drobeta', 'Craiova', 'Rimnicu Vilcea', 'Pitesti', 'Fagaras', 'Bucharest', 'Giurgiu', 'Urziceni', 'Hirsova', 'Eforie', 'Vaslui', 'Iasi', 'Neamt']
# Daftar Edge pada Graf: [('Oradea', 'Zerind'), ('Oradea', 'Sibiu'), ('Zerind', 'Arad'), ('Sibiu', 'Arad'), ('Sibiu', 'Rimnicu Vilcea'), ('Sibiu', 'Fagaras'), ('Arad', 'Timisoara'), ('Timisoara', 'Lugoj'), ('Lugoj', 'Mehadia'), ('Mehadia', 'Drobeta'), ('Drobeta', 'Craiova'), ('Craiova', 'Rimnicu Vilcea'), ('Craiova', 'Pitesti'), ('Rimnicu Vilcea', 'Pitesti'), ('Pitesti', 'Bucharest'), ('Fagaras', 'Bucharest'), ('Bucharest', 'Giurgiu'), ('Bucharest', 'Urziceni'), ('Urziceni', 'Hirsova'), ('Urziceni', 'Vaslui'), ('Hirsova', 'Eforie'), ('Vaslui', 'Iasi'), ('Iasi', 'Neamt')]
# Jumlah Node pada Graf 20
# Jumlah Edge pada Graf 23

# %% [markdown]
# Visualisasi graf

# %%
show_graph(G, pos=pos)

# %% [markdown]
# Membuat fungsi heuristik

# %%
def heuristable(a, b):
    return 0
#dibuat 0 karena ga perlu heruistik tetapi perlu librarynya

# %% [markdown]
# Menentukan jalur dari node A ke node M dengan UCS

# %%
path_node = nx.astar_path(G, 'Arad', 'Bucharest', heuristic=heuristable,
weight='weight')

# Mencari weight terkecil dari A ke M
path_length = nx.astar_path_length(G, 'Arad', 'Bucharest', heuristic=heuristable,
weight='weight')

# Cetak hasil
print("Node yang dikunjungi dari Arad ke Bucharest:", path_node)
print("Besar weight terkecil dari Arad ke Bucharest:", path_length)
# Out:
# Node yang dikunjungi dari Arad ke Bucharest: ['Arad', 'Sibiu', 'Rimnicu Vilcea', 'Pitesti', 'Bucharest']
# Besar weight terkecil dari Arad ke Bucharest: 418

# %% [markdown]
# 2. Directed Graph

# %% [markdown]
# Import library

# %%
import networkx as nx
import matplotlib.pyplot as plt

# %% [markdown]
# Function cetak plot

# %%
def show_graph(G, pos=None, title='', labels=None):
    if pos is None:
        pos = nx.spring_layout(G)

    # Kalau labels tidak diberikan, pakai nama node biasa
    if labels is None:
        labels = {node: str(node) for node in G.nodes()}

    plt.figure(figsize=(15,15))
    nx.draw(
        G,
        pos,
        with_labels=False,  # Jangan tampilkan label default
        node_color='red',
        node_size=2500,
        font_color="white",
        font_weight="bold",
        width=5
    )

    # Gambar label custom di node
    nx.draw_networkx_labels(
        G,
        pos,
        labels=labels,
        font_color='white',
        font_weight='bold'
    )

    edge_labels = nx.get_edge_attributes(G, 'weight')
    nx.draw_networkx_edge_labels(
        G,
        pos,
        edge_labels=edge_labels,
        font_color='blue',
        font_weight="bold",
        font_size=12
    )

    plt.margins(0.2)
    plt.title(title)
    plt.show()

# %% [markdown]
# Membuat POS (posisi node)

# %%
pos = {
    'Jakarta': (0, 5),
    'Bandung': (1, 3),
    'Cirebon': (2, 5),
    'Yogyakarta': (4, 3),
    'Semarang': (5, 5),
    'Surakarta': (6, 4),
    'Surabaya': (8, 5),
    'Malang': (8, 3)
}

# %% [markdown]
# Membuat directed graph dengan NetworkX

# %%
G = nx.DiGraph()
Tugas_Prak
# Menambahkan edge pada graf
G.add_weighted_edges_from(edges)

# %% [markdown]
# Print elemen graf

# %%
print("Elemen pada Graf:")
print("Daftar Node pada Graf:", G.nodes())
print("Daftar Edge pada Graf:", G.edges())
print("Jumlah Node pada Graf", G.number_of_nodes())
print("Jumlah Edge pada Graf", G.number_of_edges())
# Out:
# Elemen pada Graf:
# Daftar Node pada Graf: ['Jakarta', 'Cirebon', 'Bandung', 'Yogyakarta', 'Semarang', 'Surakarta', 'Surabaya', 'Malang']
# Daftar Edge pada Graf: [('Jakarta', 'Cirebon'), ('Jakarta', 'Bandung'), ('Cirebon', 'Semarang'), ('Cirebon', 'Yogyakarta'), ('Bandung', 'Cirebon'), ('Bandung', 'Yogyakarta'), ('Yogyakarta', 'Semarang'), ('Yogyakarta', 'Surakarta'), ('Semarang', 'Surakarta'), ('Semarang', 'Surabaya'), ('Surakarta', 'Malang'), ('Surabaya', 'Malang')]
# Jumlah Node pada Graf 8
# Jumlah Edge pada Graf 12

# %% [markdown]
# Menambahkan label start dan goal

# %%
labels = {node: node for node in G.nodes()}
labels['Bandung'] = 'A\nStart'
labels['Malang'] = 'F\nGoal'

# %% [markdown]
# Visualisasi graf

# %%
show_graph(G, pos=pos, labels=labels)

# %% [markdown]
# Membuat fungsi heuristik

# %%
def heuristable(a, b):
    return 0

# %% [markdown]
# Menentukan jalur dari node A ke node F dengan UCS

# %%
path_node = nx.astar_path(G, 'Bandung', 'Malang', heuristic=heuristable,
weight='weight')
# Mencari weight terkecil dari A ke M
path_length = nx.astar_path_length(G, 'Bandung', 'Malang', heuristic=heuristable,
weight='weight')
# Cetak hasil
print("Node yang dikunjungi dari Bandung ke Malang:", path_node)
print("Besar weight terkecil dari Bandung ke Malang:", path_length)
# Out:
# Node yang dikunjungi dari Bandung ke Malang: ['Bandung', 'Cirebon', 'Yogyakarta', 'Surakarta', 'Malang']
# Besar weight terkecil dari Bandung ke Malang: 760
